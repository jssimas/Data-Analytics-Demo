# %%
velocidade = (3, 4, 6, 7)
tempo = (20, 30, 60, 100)
plt.plot(velocidade, tempo)
plt.grid()
plt.title("Velocidade pelo tempo") 
plt.xlabel("tempo")
plt.ylabel("velocidade")
plt.show()
plt.bar(velocidade, tempo)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4994/1457817925.py in <module>
#       1 velocidade = (3, 4, 6, 7)
#       2 tempo = (20, 30, 60, 100)
# ----> 3 plt.plot(velocidade, tempo)
#       4 plt.grid()
#       5 plt.title("Velocidade pelo tempo")
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

# fig.savefig("test.png")
plt.show()

# %%
frutas = ['banana', 'maça', 'morango']
nota = ['5', '7', '9']
plt.bar(frutas, nota)
plt.show()

# %%
plt.plot([3, 4, 6, 7], [20, 30, 60, 100])
plt.grid()
plt.title("Grafico da velocidade pelo tempo")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='tempo (s)', ylabel='tensão (mV)',
       title='Tensão pelo tempo')
ax.grid()

# fig.savefig("test.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.set_yticks(np.arange(-3, 3, 0.5))
ax.set_xticks(np.arange(-3, 3, 0.5))

ax.set(xlabel='tempo (s)', ylabel='tensão (mV)',
       title='Tensão pelo tempo')
ax.grid()

# fig.savefig("test.png")
plt.show()
